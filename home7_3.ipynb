# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from time import*
browser = webdriver.Chrome()
url = "https://www.cba.am/EN/SitePages/Default.aspx"
browser.get(url)

# %%
usdexrate=browser.find_element_by_xpath('//*[@id="ctl00_PlaceHolderMain_g_863d4f31_7343_4804_bedb_aa7f55c1305a_updatePanelctl00_PlaceHolderMain_g_863d4f31_7343_4804_bedb_aa7f55c1305a"]/li[1]/em[3]')
print(usdexrate.text)
# Out:
# 478.85
